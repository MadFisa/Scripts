# %%
# %run fitting.py
# Out:
# enter grb_name:190829A
# 60.0 0.001 5 -10 2.4 2.00001 -0.01 -6

# %%
# %run multinest_marginals_corner.py mltnst_dim4_
# Out:
# enter grb_name:061201A
# model "mltnst_dim4_"
#   analysing data from mltnst_dim4_.txt
#   marginal likelihood:
#     ln Z = 61.9 +- 0.0
#   parameters:
#     $\theta_{j}$   0.67 +- 0.31
#     $log n_{0}$    -0.76 +- 0.89
#     p              2.556 +- 0.028
#     $log \epsilon_{B}$-2.74 +- 0.51
# creating marginal plot ...
# [0.6748014887966157, -0.7558022258004758, 2.5556450096024648, -2.737792828835449]
# 0.6748014887966157 -0.7558022258004758 2.5556450096024648 -2.737792828835449

# %%
# %run plotting.py
# Out:
# enter grb name: 061201A
